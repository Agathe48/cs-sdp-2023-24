# Pour k et l qui variaient entre 2 et 9, et 5 et 9. (sur 5 iter)
matrix_results_temp = [[[0.8316334183290836, 0.5515081362003998], [0.8323083845807709, 0.5097614285056603], [0.8191590420478976, 0.5096678655230009], [0.8021098945052747, 0.5070037253368451], [0.8263586820658967, 0.515264555764237]], [[0.8820808959552022, 0.579856727520615], [0.8862056897155143, 0.5615577149694302], [0.8848307584620769, 0.5740439759842462], [0.9052047397630119, 0.5619870952653713], [0.9033298335083246, 0.5652114509346656]], [[0.9286285685715714, 0.5881918386268632], [0.9214039298035098, 0.5933340717029547], [0.9356282185890705, 0.5870495130527091], [0.9171041447927604, 0.5975502042377444], [0.903904804759762, 0.596889847515324]], [[0.9388780560971951, 0.6124469494632315], [0.9491025448727564, 0.5991719926015899], [0.9285285735713215, 0.6036116008754199], [0.9407279636018199, 0.6079771309552069], [0.9375781210939453, 0.6121938596952805]], [[0.9533523323833808, 0.6107819568397596], [0.9650517474126293, 0.620176063520016], [0.9670516474176292, 0.6134396600086998], [0.9653767311634418, 0.6171800094778142], [0.9633518324083796, 0.6260746161211976]], [[0.9530273486325683, 0.6287490217874296], [0.9647017649117544, 0.6478451870511647], [0.9614019299035048, 0.626767210425759], [0.9756512174391281, 0.6234982331031445], [0.9433778311084445, 0.6265004579325295]], [[0.9712264386780661, 0.6360144056245601], [0.9697265136743163, 0.6237766434720188], [0.9664516774161291, 0.6312091472749429], [0.964176791160442, 0.626228622070559], [0.9699015049247538, 0.6295294732525942]], [[0.9747262636868157, 0.627525872275172], [0.97977601119944, 0.6356242886338221], [0.9779011049447528, 0.6294262397452363], [0.9825508724563772, 0.6427337216674578], [0.97997600119994, 0.6194931934861221]]] # en 20 min

# l = 5, k variant de 3 à 9
list_new_init_2 = [[0.9550522473876306, 0.6254821680555431], [0.9779761011949403, 0.6242548101089234], [0.983950802459877, 0.6094660017880333], [0.991700414979251, 0.6159219888309352], [0.9986750662466877, 0.6615412248312111], [0.9995750212489376, 0.6706278520728097], [0.9980000999950003, 0.6277113933608587]] # en 40 min sur tout le dataset

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
x = [i for i in range(1, 15)]
y_random_init = [list_temp[i][0] for i in range(14)]
y_classtwocluster_init = [list_temp_new_init[i][0] for i in range(14)]
y_classtwocluster_init_several_cluster = [list_temp_new_init_several_clusters[i][0] for i in range(14)]
y_20_random_init = [list_20_random_init[i][0] for i in range(14)]

ax.scatter(x, y_random_init, label='Random initialisation')
ax.scatter(x, y_classtwocluster_init, label='TwoClustersMIP initialisation')
ax.scatter(x, y_classtwocluster_init_several_cluster, label='TwoClustersMIP (several clusters allowed) initialisation')
ax.scatter(x, y_20_random_init, label='Random 20 TwoClustersMIP initialisations')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(1.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.05))

ax.set_ylim(0.5, 1)

ax.legend(loc = 'lower right')
ax.set_xlabel('Number of iterations')
ax.set_ylabel('Percentage of explained pairs')
ax.grid()

fig.savefig('../images/' + 'Metric_1_comparison_v2' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_1_comparison_v2' + '.png', dpi=300, format='png', bbox_inches="tight")

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
x = [i for i in range(1, 15)]
y_random_init = [list_temp[i][1] for i in range(14)]
y_classtwocluster_init = [list_temp_new_init[i][1] for i in range(14)]
y_classtwocluster_init_several_cluster = [list_temp_new_init_several_clusters[i][1] for i in range(14)]
y_20_random_init = [list_20_random_init[i][1] for i in range(14)]

ax.scatter(x, y_random_init, label='Random initialisation')
ax.scatter(x, y_classtwocluster_init, label='TwoClustersMIP initialisation')
ax.scatter(x, y_classtwocluster_init_several_cluster, label='TwoClustersMIP (several clusters allowed) initialisation')
ax.scatter(x, y_20_random_init, label='Random 20 TwoClustersMIP initialisations')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(1.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.05))

ax.set_ylim(0.4, 0.8)

ax.legend(loc = 'lower right')
ax.set_xlabel('Number of iterations')
ax.set_ylabel('Percentage of clustering intersection')
ax.grid()

fig.savefig('../images/' + 'Metric_2_comparison_v2' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_2_comparison_v2' + '.png', dpi=300, format='png', bbox_inches="tight")

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
l = [i for i in range(5, 10)]
k = [i for i in range(2, 10)]

m1_l_5 = [matrix_results_temp[i][0][0] for i in range(8)]
m1_l_6 = [matrix_results_temp[i][1][0] for i in range(8)]
m1_l_7 = [matrix_results_temp[i][2][0] for i in range(8)]
m1_l_8 = [matrix_results_temp[i][3][0] for i in range(8)]
m1_l_9 = [matrix_results_temp[i][4][0] for i in range(8)]

ax.plot(k, m1_l_5, label='l = 5', color='blue')
ax.scatter(k, m1_l_5, color='blue', marker='o')
ax.plot(k, m1_l_6, label='l = 6',color='orange')
ax.scatter(k, m1_l_6, color='orange', marker='o')
ax.plot(k, m1_l_7, label='l = 7', color='green')
ax.scatter(k, m1_l_7, color='green', marker='o')
ax.plot(k, m1_l_8, label='l = 8', color='red')
ax.scatter(k, m1_l_8, color='red', marker='o')
ax.plot(k, m1_l_9, label='l = 9', color='purple')
ax.scatter(k, m1_l_9, color='purple', marker='o')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(1.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.05))

ax.set_ylim(0.75, 1)
ax.set_xlim(2, 9)

ax.legend(loc = 'lower right')
ax.set_xlabel('Number of clusters k')
ax.set_ylabel('Percentage of explained pairs')
ax.grid()

fig.savefig('../images/' + 'Metric_1_comparison_for_values_of_k_and_l' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_1_comparison_for_values_of_k_and_l' + '.png', dpi=300, format='png', bbox_inches="tight")

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
l = [i for i in range(5, 10)]
k = [i for i in range(2, 10)]

m1_l_5 = [matrix_results_temp[i][0][1] for i in range(8)]
m1_l_6 = [matrix_results_temp[i][1][1] for i in range(8)]
m1_l_7 = [matrix_results_temp[i][2][1] for i in range(8)]
m1_l_8 = [matrix_results_temp[i][3][1] for i in range(8)]
m1_l_9 = [matrix_results_temp[i][4][1] for i in range(8)]

ax.plot(k, m1_l_5, label='l = 5', color='blue')
ax.scatter(k, m1_l_5, color='blue', marker='o')
ax.plot(k, m1_l_6, label='l = 6',color='orange')
ax.scatter(k, m1_l_6, color='orange', marker='o')
ax.plot(k, m1_l_7, label='l = 7', color='green')
ax.scatter(k, m1_l_7, color='green', marker='o')
ax.plot(k, m1_l_8, label='l = 8', color='red')
ax.scatter(k, m1_l_8, color='red', marker='o')
ax.plot(k, m1_l_9, label='l = 9', color='purple')
ax.scatter(k, m1_l_9, color='purple', marker='o')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(1.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.05))

ax.set_ylim(0.4, 0.7)
ax.set_xlim(2, 9)

ax.legend(loc = 'lower right')
ax.set_xlabel('Number of clusters k')
ax.set_ylabel('Percentage of clustering intersection')
ax.grid()

fig.savefig('../images/' + 'Metric_2_comparison_for_values_of_k_and_l' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_2_comparison_for_values_of_k_and_l' + '.png', dpi=300, format='png', bbox_inches="tight")

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
x = [i for i in range(3, 10)]
y_new_init_2_pairs = [list_new_init_2[i][0] for i in range(7)]
# y_new_init_2_cluster = [list_new_init_2[i][1] for i in range(7)]

ax.scatter(x, y_new_init_2_pairs)

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(1.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.025))

ax.set_ylim(0.9, 1)
ax.set_xlim(2, 10)

# ax.legend(loc = 'lower right')
ax.set_xlabel('Number of clusters k')
ax.set_ylabel('Percentage of explained pairs')
ax.grid()

fig.savefig('../images/' + 'Metric_1_Scalabilite' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_1Scalabilite' + '.png', dpi=300, format='png', bbox_inches="tight")

# %%
list_several_init = [[0.9052297385130743, 0.5681390501110679], [0.8898055097245138, 0.5782071387418355], [0.9007799610019499, 0.5857415224036429], [0.8690065496725163, 0.5648487656365163], [0.9241037948102595, 0.6321554075542392], [0.9023048847557622, 0.5913532390178821], [0.8893055347232638, 0.5751308557169077], [0.9156042197890105, 0.5888854453554915], [0.8544822758862057, 0.5530600898019398], [0.8758312084395781, 0.5653726313459333], [0.9100044997750113, 0.580652245355783], [0.9046047697615119, 0.5658852204011134], [0.8790060496975152, 0.5647715289293659], [0.871756412179391, 0.563377430988454], [0.8762811859407029, 0.586186975244123], [0.903504824758762, 0.5806876601996255], [0.8694065296735163, 0.5594182779298824], [0.8827058647067647, 0.582666031819281], [0.8783060846957652, 0.5919339117167038], [0.8985050747462627, 0.589504352686668]]
len(list_several_init)
# Out:
# 20

# %%
fsize = [7, 5]
plt.rc('font', family = 'serif', size = '14')
plt.rc('legend', fontsize = 13)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = fsize

fig, ax = plt.subplots(1, 1)

# list of iterations
x = [i for i in range(1, len(list_several_init)+1)]

y_m1_several_init = [list_several_init[i][0] for i in range(len(list_several_init))]
y_m2_several_init = [list_several_init[i][1] for i in range(len(list_several_init))]
# y_new_init_2_cluster = [list_new_init_2[i][1] for i in range(7)]

ax.scatter(x, y_m1_several_init, label = 'Explained pairs')
ax.scatter(x, y_m2_several_init, label = 'Clustering intersection')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1)) # put y axis in percentage, 1 is for 100%
ax.xaxis.set_major_locator(mtick.MultipleLocator(2.00))
ax.yaxis.set_major_locator(mtick.MultipleLocator(0.05))

ax.set_ylim(0.4, 1)
ax.set_xlim(0, 21)

ax.legend(loc = 'lower right')
ax.set_xlabel('Initilisation id')
ax.set_ylabel('Percentage')
ax.grid()

fig.savefig('../images/' + 'Metric_1_several_init' + '.pdf', format='pdf', bbox_inches="tight")
fig.savefig('../images/'  + 'Metric_1_several_init' + '.png', dpi=300, format='png', bbox_inches="tight")
